# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Елена, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам аналитика. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Критичные ошибки, которые обязательно нужно исправить.
# </div>
#
# Я не смогу принять проект, если в нём будет хотя бы одна критичная ошибка или несколько некритичных ошибок - тогда проект нужно будет немного доработать. Но это нестрашно - я обязательно дам тебе подсказку или укажу верное направление.
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <br/>
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка" data-toc-modified-id="Подготовка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка</a></span></li><li><span><a href="#Анализ" data-toc-modified-id="Анализ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ</a></span></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение</a></span></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование</a></span></li><li><span><a href="#Обший-вывод" data-toc-modified-id="Обший-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Обший вывод</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Вам нужно:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
#
#
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отличное вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!
#
# Спасибо, что сделала оглавление, как в плагине toc, так и с гиперссылками - теперь по проекту удобно перемещаться:)

# %% [markdown]
# ## Подготовка

# %%
#загрузим нужные библиотеки
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import TimeSeriesSplit
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично!
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Я вижу, что ячейки в твоей тетрадке начинаются не с 1. Перед отправкой проекта стоит проверять работоспособность кода — это можно сделать, нажав на панели Jupiter Hub ``Kernel`` и ``Restart & Run All`` (см скриншот ниже).
#
# ![](https://i.postimg.cc/yd19rYf6/Screenshot-428.png)
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Этот комментарий не учтён.
#
# </div>

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено!
# </div>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# загрузим данные, изменив тип данных Datetime с object на datetime64
# и установив индекс таблицы равным столбцу Datetime. 
# try:
#     data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/временные ряды_прогнозирование заказов такси/taxi.csv', parse_dates=[0], index_col=[0])
# except:
#     data = pd.read_csv('/datasets/taxi.csv', parse_dates=[0], index_col=[0])

# %%
pth1 = '/content/drive/MyDrive/Colab Notebooks/временные ряды_прогнозирование заказов такси/taxi.csv'
pth2 = '/datasets/taxi.csv'

if os.path.exists(pth1):
    data = pd.read_csv(pth1, parse_dates=[0], index_col=[0])
elif os.path.exists(pth2):
    data = pd.read_csv(pth2, parse_dates=[0], index_col=[0])
else:
    print('Something is wrong')

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Здорово, что ты используешь конструкцию ``try-except`` для путей файлов. Но еще лучше использовать библиотеку ``os``:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *Спасибо за совет, использовала!*
# </div>

# %%
# изучим данные
data.head()
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %%
data.describe()
# Out:
#          num_orders
# count  26496.000000
# mean      14.070463
# std        9.211330
# min        0.000000
# 25%        8.000000
# 50%       13.000000
# 75%       19.000000
# max      119.000000

# %%
#проверим на наличие пропусков
data.isna().sum()
# Out:
# num_orders    0
# dtype: int64

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Данные посмотрели и описали - хорошо!
# </div>

# %%
# отсортируем индекс
data = data.sort_index()

# %%
#проверим, в хронологическом ли порядке расположены даты и время
print(data.index.is_monotonic)
# Out:
# True

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отсортировали индексы и проверили их на монотонность - отлично!
# </div>

# %%
# ресемплируем данные по 1 часу
data = data.resample('1H').sum()

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Сделали ресэмплирование по 1 часу и применили суммирование как агрегационную функцию - отлично, самое верное решение с точки зрения интерпретации результатов.
# </div>

# %% [markdown]
# ###Вывод 1.
#
# У нас есть данные заказов такси с марта по август 2018 года. Мы изменили тип данных Datetime с object на datetime64 и установили индекс таблицы равным столбцу Datetime. Проверили на наличие пропусков, на монотонность и ресемплировали данные по часу (изначально данные за каждые 10 минут).

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Хороший промежуточный вывод - прекрасно!
# </div>

# %% [markdown]
# ## Анализ

# %%
# построим график временного рядя
data.plot(figsize=(12,8))
plt.xlabel('Дата', fontsize=14)
plt.ylabel('Количество заказов такси', fontsize=14)
plt.title('Количество заказов такси март-август 2018', fontsize=16)
plt.legend()
plt.show()

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Визуализировали временной ряд - хорошо!
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Над самой визуализацией стоит чуть поработать:
# 1. Стоит подписать названия осей X и Y.
# 2. Также стоит дать название графику.
# 3. Технические комментарии типа `<matplotlib.axes._subplots.AxesSubplot at 0x7f377f1b2f50>` стоит убирать: это можно сделать, поставив точку с запятой в последней строке кода в блоке визуализации, либо сделать последней строкой кода этого блока метод `plt.show()`.
# 4. Стоит оптимизировать размер графика - его стоит сделать побольше, но важно не перестараться:)
#
# Несколько таких нехитрых приёмов очень повысят ценность твоей визуализации:)
#
# Будет здорово, если ты учтёшь эти комментарии для всех графиков в твоей работе.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Этот комментарий не учтён.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *исправила*
# </div>

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено!
# </div>

# %%
# разложим временной ряд на тренд и сезонную компоненту
decomposed = seasonal_decompose(data)

plt.figure(figsize=(8, 12))
plt.subplot(311)
decomposed.seasonal.plot(ax=plt.gca())
# Чтобы график корректно отобразился, указываем его
# оси ax, равными plt.gca() (англ. get current axis,
# получить текущие оси)
plt.title('Seasonality')
plt.subplot(312)
decomposed.trend.plot(ax=plt.gca())
plt.title('Trend')
plt.subplot(313)
decomposed.resid.plot(ax=plt.gca())
plt.title('Residuals')
plt.tight_layout()

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Декомпозировали временной ряд и визуализировали его компоненты - хорошо!
# </div>

# %%
# построим график сезонной составляющей за июль
plt.figure(figsize=(8, 12))
plt.subplot(311)
decomposed.seasonal['2018-07-01':'2018-07-31'].plot(ax=plt.gca())
plt.title('Seasonality')
plt.subplot(312)
decomposed.trend['2018-07-01':'2018-07-31'].plot(ax=plt.gca())
plt.title('Trend')
plt.subplot(313)
decomposed.resid['2018-07-01':'2018-07-31'].plot(ax=plt.gca())
plt.title('Residuals')
plt.tight_layout()

# %% [markdown]
# По графикам виден тренд на увеличение количества заказов с течением времени

# %%
# построим график сезонной составляющей за двое суток в июле
plt.figure(figsize=(8, 12))
plt.subplot(311)
decomposed.seasonal['2018-07-01':'2018-07-02'].plot(ax=plt.gca())
plt.title('Seasonality')
plt.subplot(312)
decomposed.trend['2018-07-01':'2018-07-31'].plot(ax=plt.gca())
plt.title('Trend')
plt.subplot(313)
decomposed.resid['2018-07-01':'2018-07-31'].plot(ax=plt.gca())
plt.title('Residuals')
plt.tight_layout()

# %% [markdown]
# По графику видно, что больше всего заказов приходися на 12 ночи, а меньше всего на 6 утра.

# %% [markdown]
# Проверим стационарность временного ряда.
#
# Для этого найдем разности временного ряда (англ. time series difference) — это набор разностей между соседними элементами временного ряда, т. е. из каждого значения вычитается предыдущее.
# Для поиска разностей временного ряда применяется метод shift() (англ. «сдвиг»). Все значения он сдвигает вдоль временной оси на один шаг вперёд.

# %%
data1 = data - data.shift()
data1['mean'] = data1['num_orders'].rolling(15).mean()
data1['std'] = data1['num_orders'].rolling(15).std()
data1.plot(figsize=(12,10))
plt.show()

# %% [markdown]
# По графику видно, что ряд достаточно стационарен, поскольку его среднее значение и стандартное отклонение не сильно меняются.

# %% [markdown]
# Проведем тест Дики-Фуллера

# %%
result = adfuller(data['num_orders'])
print('ADF Statistic: {}'.format(result[0]))
print('p-value: {}'.format(result[1]))
print('Critical values:')
for key, value in result[4].items():
  print('\t {}: {}'.format(key, value))
# Out:
# ADF Statistic: -3.06892428902795
# p-value: 0.02894005140261338
# Critical values:
# 	 1%: -3.431842162413052
# 	 5%: -2.8621993540813637
# 	 10%: -2.567120978470452

# %% [markdown]
# Поскольку p-value меньше порогового значения 0.05, значит мы может отвергнуть нулевую гипотезу, что ряд нестационарный, а значит он стационарный.

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Сделали анологичный шаг на более коротком промежутке - хорошо!
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Сезонную компоненту стоит также исследовать за более короткий промежуток - например, за 2-3 суток. Таким образом можно будет понять природу сезонности, а также понять, в какое время суток существуют пики заказов, а в какое заказов наоборот меньше всего.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Этот комментарий не учтён.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *добавила анализ сезонной комноненты за 2 дня (см.выше)*
# </div>

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Всё отлично!
# </div>

# %% [markdown]
# Создадим признаки для задачи прогнозирования

# %%
#создадим признаки для горизонта прогнозирования в 1 шаг
def make_features(data, max_lag, rolling_mean_size):
    data['month'] = data.index.month
    data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    data['hour'] = data.index.dayofweek
    # вычислим отстающие значения
    # добавим новый аргумент max_lag, который задаст максимальный размер отставания. 
    # новые признаки назовем: 'lag_1', 'lag_2' — и до величины max_lag.
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)# 
    # вычислим скользящее среднее и добавим его как признак 'rolling_mean'.
    data['rolling_mean'] = data['num_orders'].shift().rolling(rolling_mean_size).mean()

# зададим отстающие признаки 24, а скользящее среднее 10
make_features(data, 24, 10)
print(data.head())
# Out:
#                      num_orders  month  day  dayofweek  hour  lag_1  lag_2  \
# datetime
# 2018-03-01 00:00:00         124      3    1          3     3    NaN    NaN
# 2018-03-01 01:00:00          85      3    1          3     3  124.0    NaN
# 2018-03-01 02:00:00          71      3    1          3     3   85.0  124.0
# 2018-03-01 03:00:00          66      3    1          3     3   71.0   85.0
# 2018-03-01 04:00:00          43      3    1          3     3   66.0   71.0
#
#                      lag_3  lag_4  lag_5  ...  lag_16  lag_17  lag_18  lag_19  \
# datetime                                  ...
# 2018-03-01 00:00:00    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN
# 2018-03-01 01:00:00    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN
# 2018-03-01 02:00:00    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN
# 2018-03-01 03:00:00  124.0    NaN    NaN  ...     NaN     NaN     NaN     NaN
# ...

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Сделали и применили функцию для обогащения данных новыми признаками - хорошо!
# </div>

# %%
# удалим пропуски
data.dropna(inplace=True)

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Удалили пропущенные значения, появившиеся в ходе создания лаговых переменных - отлично!
# </div>

# %%
data.head()
# Out:
#                      num_orders  month  day  dayofweek  hour  lag_1  lag_2  \
# datetime
# 2018-03-02 00:00:00          90      3    2          4     4   58.0  113.0
# 2018-03-02 01:00:00         120      3    2          4     4   90.0   58.0
# 2018-03-02 02:00:00          75      3    2          4     4  120.0   90.0
# 2018-03-02 03:00:00          64      3    2          4     4   75.0  120.0
# 2018-03-02 04:00:00          20      3    2          4     4   64.0   75.0
#
#                      lag_3  lag_4  lag_5  ...  lag_16  lag_17  lag_18  lag_19  \
# datetime                                  ...
# 2018-03-02 00:00:00   66.0   61.0   45.0  ...    34.0    15.0    12.0     6.0
# 2018-03-02 01:00:00  113.0   66.0   61.0  ...    69.0    34.0    15.0    12.0
# 2018-03-02 02:00:00   58.0  113.0   66.0  ...    64.0    69.0    34.0    15.0
# 2018-03-02 03:00:00   90.0   58.0  113.0  ...    96.0    64.0    69.0    34.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4392 entries, 2018-03-02 00:00:00 to 2018-08-31 23:00:00
# Freq: H
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   num_orders    4392 non-null   int64
#  1   month         4392 non-null   int64
#  2   day           4392 non-null   int64
#  3   dayofweek     4392 non-null   int64
#  4   hour          4392 non-null   int64
#  5   lag_1         4392 non-null   float64
#  6   lag_2         4392 non-null   float64
#  7   lag_3         4392 non-null   float64
#  8   lag_4         4392 non-null   float64
#  9   lag_5         4392 non-null   float64
#  10  lag_6         4392 non-null   float64
#  11  lag_7         4392 non-null   float64
#  12  lag_8         4392 non-null   float64
#  13  lag_9         4392 non-null   float64
#  14  lag_10        4392 non-null   float64
#  15  lag_11        4392 non-null   float64
#  16  lag_12        4392 non-null   float64
# ...

# %% [markdown]
# ###Вывод 2.
#
# В этом разделе мы проанализировали графики временного ряда, сначала по всем данным, затем по месяцу и по 2 дням и выявили тренд на увеличение количества заказов с течением времени, а также то, что максимум заказов приходится на 12 ночи, а минимум на 6 утра. Проверили на стационарность временного ряда. Затем мы создали календарные признаки для месяца, дня, дня недели и часа и отстающие признаки, а также скользящее среднее. Удалили пропуски и получили таблицу с 29 признаками, готовую для построения моделей.

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отличный промежуточный вывод!
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Дополнительно стоит оценить стационарность ряда и сделать об этом вывод. Сделать это можно с помощью сглаживания скользящим средним и последующей визуализацией сглаженного ряда на графике - это самый простой способ, и в рамках проекта этот способ допустим. В реальных же задачах с временными рядами, в особенности - с финансовыми данными или биржевыми котировками, график не всегда поможет достоверно оценить стационарность ряда. Поэтому для оценки стационарности ряда лучше использовать тест Дики — Фуллера (подробнее о нём можно глянуть тут: https://www.statsmodels.org/dev/generated/statsmodels.tsa.stattools.adfuller.html) - он даст наиболее точный результат. Если попробуешь оба способа - будет здорово:)
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Этот комментарий не учтён.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *попробовала обоими способами*
# </div>

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть!
# </div>

# %% [markdown]
# ## Обучение

# %% [markdown]
# Разделим данные на обучающую и тестовую выборки и построим разные модели, найдя для них наилучшие гиперпараметры.

# %%
# разделим выборки на обучающую и тестовую
train, test = train_test_split(data, shuffle=False, test_size=0.1)
train = train.dropna()

features_train = train.drop(['num_orders'], axis=1)
target_train = train['num_orders']
 
features_test = test.drop(['num_orders'], axis=1)
target_test = test['num_orders']

# проверим размер выборок
display(train.shape)
display(test.shape)
# проверим корректность деления
print(train.index.min(), train.index.max())
print(test.index.min(), test.index.max())
# Out:
# (3952, 30)
# (440, 30)
# 2018-03-02 00:00:00 2018-08-13 15:00:00
# 2018-08-13 16:00:00 2018-08-31 23:00:00

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
# Сплитование сделано корректно как с точки зрения учёта специфики временного ряда (отключено перемешивание), так и размера тестовой выборки.
# </div>

# %% [markdown]
# ###3.1 Модель линейной регрессии

# %%
model = LinearRegression()
 
model.fit(features_train, target_train)
train_pred = model.predict(features_train)
rmse = mean_squared_error(target_train, train_pred)**0.5
print(rmse)
# Out:
# 25.824713299765502

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
# Обучили модель линейной регрессии, получили промежуточную оценку качества - хорошо!
# </div>

# %% [markdown]
# ###3.2 Модель случайного леса

# %%
#разделим данные на обучающую и тестовые выборки
#на обучающую выделим 80%, на тестовую - 20%
df_train_rf, df_test_rf = train_test_split(data, test_size=0.20, shuffle=False, random_state=12345) 

# #создадим в обучающей выборке переменные для признаков и целевого признака 
features_train_rf = df_train_rf.drop(['num_orders'], axis=1)
target_train_rf = df_train_rf['num_orders']

# #разделим тестовую выборку пополам на тестовую и валидационную
df_valid_rf, df_test_rf = train_test_split(df_test_rf, test_size=0.50, random_state=12345)

# #создадим в валидационной и тестовой выборках переменные для признаков и целевого признака
features_valid_rf = df_valid_rf.drop(['num_orders'], axis=1)
target_valid_rf = df_valid_rf['num_orders']
features_test_rf = df_test_rf.drop(['num_orders'], axis=1)
target_test_rf = df_test_rf['num_orders']

# %%
#проверим, как поделились выборки
print(df_train_rf.shape)#80%
print(df_test_rf.shape)#10%
print(df_valid_rf.shape)#10%
# Out:
# (3513, 30)
# (440, 30)
# (439, 30)

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Здесь некорректно выполнено сплитование. При делении на тренировочный и тестовый сеты размер тестового должен быть 10% от набора данных по условию проекта, ты сделала 20%:)
#
# Также валидационную выборку лучше выделять из тренировочных данных, а не из тестовых - иначе на тест остаётся мало примеров. Делить в пропорции 50/50 - не лучшая затея:) Для валидации вполне подойдут те же 10% от тренировочного сета.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *мои выборки имеют размер 80%-10%-10%. сначала я поделила на тренировочную и тестовую в пропорции 80%-20%, а затем поделила тестовую пополам. в чем здесь ошибка?*
# </div>

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.4 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
# Да, действительно, здесь я был неправ - исходный способ деления был корректен, прошу прощения.
# </div>

# %%
# найдем наилучшую глубину дерева
for depth in range(3, 20, 3):
    model = RandomForestRegressor(random_state=12345, max_depth = depth)
    model.fit(features_train_rf, target_train_rf)
    predictions_valid_rf = model.predict(features_valid_rf)
    rmse = mean_squared_error(target_valid_rf, predictions_valid_rf)**0.5
    print('Глубина:', depth)
    print('RMSE для решающего дерева:', rmse)
    print('')
print()
# Out:
# Глубина: 3
# RMSE для решающего дерева: 55.387622174369625
#
# Глубина: 6
# RMSE для решающего дерева: 45.14047266154682
#
# Глубина: 9
# RMSE для решающего дерева: 42.37536050903004
#
# Глубина: 12
# RMSE для решающего дерева: 41.420482206362585
#
# Глубина: 15
# RMSE для решающего дерева: 41.2694460089074
#
# Глубина: 18
# RMSE для решающего дерева: 41.34062061241398

# %% [markdown]
# Возьмем глубину дерева 15

# %%
# найдем наилучшее количество деревьев
for est in [100, 500, 1000]:
    model = RandomForestRegressor(random_state=12345, 
                                   n_estimators=est, 
                                   max_depth=15)
    model.fit(features_train_rf, target_train_rf)
    predictions_valid_rf = model.predict(features_valid_rf)
    rmse = mean_squared_error(target_valid_rf, predictions_valid_rf)**0.5
    print('Количество деревьев:', est)
    print('RMSE для случайного леса:', rmse)
    print('')
print()
# Out:
# Количество деревьев: 100
# RMSE для случайного леса: 41.2694460089074
#
# Количество деревьев: 500
# RMSE для случайного леса: 41.39673784450648
#
# Количество деревьев: 1000
# RMSE для случайного леса: 41.39676400396962

# %%
# проверим на тестовой выборке
model = RandomForestRegressor(random_state=12345, 
                                   n_estimators=100, 
                                   max_depth=15)
model.fit(features_train_rf, target_train_rf)
features_train_rf = pd.concat([features_train_rf, features_valid_rf])
target_train_rf = pd.concat([target_train_rf, target_valid_rf])
model.fit(features_train_rf, target_train_rf)
predict = model.predict(features_test_rf)
print(mean_squared_error(target_test, predict, squared=False))
# Out:
# 72.39618182708573

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
# То же сделали и для решающего дерева!
# </div>

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
# Аналогично для случайного леса.
# </div>

# %% [markdown]
# ###3.3 LightGMB

# %%
#разделим данные на обучающую и тестовые выборки
#на обучающую выделим 80%, на тестовую - 20%
# df_train_lg, df_test_lg = train_test_split(data, test_size=0.20, shuffle=False, random_state=12345) 

# # #создадим в обучающей выборке переменные для признаков и целевого признака 
# features_train_lg = df_train_lg.drop(['num_orders'], axis=1)
# target_train_lg = df_train_lg['num_orders']

# # #разделим тестовую выборку пополам на тестовую и валидационную
# df_valid_lg, df_test_lg = train_test_split(df_test_lg, test_size=0.50, random_state=12345)

# # #создадим в валидационной и тестовой выборках переменные для признаков и целевого признака
# features_valid_lg = df_valid_lg.drop(['num_orders'], axis=1)
# target_valid_lg = df_valid_lg['num_orders']
# features_test_lg = df_test_lg.drop(['num_orders'], axis=1)
# target_test_lg = df_test_lg['num_orders']

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Для LightGBM аналогичное замечание про процесс сплитования.
#
# </div>

# %%
#проверим, как поделились выборки
# print(df_train_lg.shape)#80%
# print(df_test_lg.shape)#10%
# print(df_valid_lg.shape)#10%

# %%
# построим модель без подбора гиперпараметров
# model = lgb.LGBMRegressor(random_state=12345)
# model.fit(features_train, target_train)
# predictions_train = model.predict(features_train)
# rmse = mean_squared_error(target_train, predictions_train)**0.5
# print(rmse)

# %%
# проверим модель без подбора гиперпараметров
model = lgb.LGBMRegressor(random_state=12345)
model.fit(features_train, target_train)
predictions_test = model.predict(features_test)
rmse = mean_squared_error(target_test, predictions_test)**0.5
print(rmse)
# Out:
# 41.51113854061593

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
# Попробовали дефолтный LightGBM - хорошо!
# </div>

# %%
# найдем наилучшие гиперпараметры
param_grid = {'n_estimators': [100, 500, 1000], 'num_leaves': [n for n in range(20, 300, 20)]}
time_split = TimeSeriesSplit(n_splits=5)

# %%
'''не буду еще раз запускать подбор гиперпараметров'''
# model = lgb.LGBMRegressor(random_state=12345)

tuning_model=GridSearchCV(estimator=model,
                          param_grid=param_grid,
                          scoring='neg_root_mean_squared_error',
                          cv=time_split,
                          verbose=3)

tuning_model.fit(features_train, target_train)
display(tuning_model.best_params_)
display(tuning_model.best_score_*-1)

# %% [markdown]
# При подборе гиперпараметров методом GridSearchCV модель показала наилучшее значение метрики RMSE, поэтому будем тестировать с учетом этих гиперпараметров.

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
# Сделали подбор параметров для LightGBM с помощью GridSearchCV - хорошо! Также очень здорово, что провела корректную кросс-валидацию временного ряда с применением TimeSeriesSplit!
# </div>

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Концептуально промежуточное тестирование проведено не очень корректно. Тестирование модели на тренировочных данных - не совсем корректное действие, оно, скорее, покажет, насколько хорошо модель усвоила тренировочный сет, но не говорит о качестве предсказания. Формально ты делаешь что-то сродни коэффициенту детерминации - показываешь, насколько смоги объяснить обучающую выборку.
#
# Для проведения промежуточного тестирования при подборе гиперпараметров обычно дополнительно выделяют валидационную выборку (если не говорим про подбор с помощью GridSearchCV - в этом случае валидация проводится в процессе обучения внутри инструмента, поэтому дополнитльно выделять ничего не нужно) и промежуточно тестируются на ней. После определения оптимальных гиперпараметров модель снова обучается на тренировочных данных (допускает объединение валидационной выборки с тренировочной) и тестируется на тестовой выборке.
#
# Разницу в процессе валидации ты можешь видеть внутри своего же блока: ты сделала вывод о том, что LGBMRegressor при использовании GridSearchCV показал результат хуже, чем на дефолтных параметрах. Однако разница обусловлена тем, что GridSearchCV провёл корректную валидацию (обучение на тренировочном сете и промежуточное тестирование на валидации), а на дефолтных параметрах ты протестировала модель на обучающей выборке и получила низкую ошибку:)
#
# Резюме: для промежуточного тестирования модели при подборе гиперпараметров руками, а не через GridSearchCV, стоит выделять валидационную выборку и тестировать промежуточные модели на ней. При использовании GridSearchCV этого делать не надо - алгоритм сам отщипнёт от тренировочного сета кусочки для внутненней кросс-валидации в соответствии с правилом, переданным параметру `cv`.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *UPD: прошу прощения, кажется в прошлый раз я отправила старую версию.
#
#
# Добавила валидационную выборку и протестировала на ней модель случайного леса и дефолтный LightGBM. Не совсем поняла, как валидировать случайный лес: нужно подобрать гиперпараметры вручную и потом проверить на валидационной выборке, как сделала я, или нужно как-то по-другому?*
# </div>

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Такое бывает, ничего страшного:)
#
# Валидацию всё же нужно проводить чуть-чуть по-другому - давай разбираться:)
#
# При работе с RandomForest ты сначала обучаешь модель на тренировочной выборке во время подбора гиперпараметров. Далее на каждой итерации подбора ты тестируешь эти параметры на той же тренировочной выборке - тут твоя основная ошибка: при тестировании модели на том же наборе данных, на котором она училась, ошибка всегда будет минимальной. Обучать модель нужно всегда на тренировочной выборке, тестировать на валидации при подборе параметров, а тетсировать финальную модель всегда на тестовой выборке. Для наглядности изборажу концептуально 2 сценария работы с выборками при работе с моделью:
#
# 1. Используем дефолтные параметры без подбора:
#
#
#     features_train, features_test, target_train, target_test  = train_test_split(features, target, test_size=0.10, shuffle=False, random_state=12345)
#     model.fit(features_train, target_train)
#     predict = model.predict(features_test)
#     print(mean_squared_error(target_test, predict, squared=False))
#
# Здесь мы обучились на тренировочной выборке и сделали тестирование на тестовой выборке, валидацию не проводили - всё просто:)
#
# 2. Подбираем параметры руками:
#
#
#     features_train, features_test, target_train, target_test  = train_test_split(features, target, test_size=0.10, shuffle=False, random_state=12345)
#     features_train, features_valid, target_train, target_valid  = train_test_split(features_train, target_train, test_size=0.10, shuffle=False, random_state=12345) #дополнительно выделяем валидационную выборку из тренировочной
#     #в целом можно выделить и из тестовой, но тогда для финального тестирования останется маловато данных
#
#     for param in [100, 200, 300]:
#         model=RandomForestRegressor(n_estimators=param)
#         model.fit(features_train, target_train)
#         predict = model.predict(features_valid)
#         print(param, mean_squared_error(target_valid, predict, squared=False))
#
#     #определили лучший параметр `best_param`
#     best_param = 300
#
#     model=RandomForestRegressor(n_estimators=best_param)
#     model.fit(features_train, target_train)
#     #допускается объединение тренировочного и валидационного наборов при итоговом обучении
#     features_train = pd.concat([features_train, features_valid])
#     target_train = pd.concat([target_train, target_valid])
#     model.fit(features_train, target_train)
#     predict = model.predict(features_test)
#     print(mean_squared_error(target_test, predict, squared=False))
#
# Здесь мы реализовали ручной подбор параметров, при этом промежуточное тестирование делали на валидационной выборке. Далее после поиска лучшего параметра заново обучились на тренировочном сете (можно объединить с валидационным) и сделали финальное тестирование на тестовой выборке.
#
#
# По применению `GridSearch` всё верно:)
#
# Надеюсь, из этого комментария стало понятно, как стоит проводить ручную валидацию.
#
# </div>

# %% [markdown]
# ###Вывод 3.
#
# Мы разделили данные на обучающую и тестовую выборки и обучили модели линейной регрессии, случайного леса и LightGBM. Наилучшее значение метрики RMSE оказалось у LightGBM, на ней и будем тестировать.

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
# Есть промежуточный вывод - хорошо! Возможно, изменится после изменения процесса валидации:)
# </div>

# %% [markdown]
# ## Тестирование

# %%
# протестируем наилучшую модель на тестовой выборке
model = lgb.LGBMRegressor(random_state=12345, n_estimators=100, num_leaves=20)
model.fit(features_train, target_train)
predictions_test = model.predict(features_test)
rmse = mean_squared_error(target_test, predictions_test)**0.5
print(rmse)
# Out:
# 41.339631667888476

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
# Протестировали модель на тестовой выборке - отлично, хороший результат! Трешхолд проекта по метрике выдержан!
# </div>

# %%
# построим график для исходных данных и для предсказанных
predictions_test = pd.Series(predictions_test, index=target_test.index)
plt.figure(figsize=(20,10))
plt.xlabel('дата', fontsize=14)
plt.ylabel('число заказов',fontsize=14)
plt.plot(target_test, label='исходная выборка')
plt.plot(predictions_test, label='предсказания')
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
# Здорово, что визуализировал расхождения между предсказаниями и реальными значениями - видим, что модель сильно ошибается в пиковые моменты, но в спокойные моменты справляется неплохо.
# </div>

# %% [markdown]
# ###Вывод 4.
#
# Показатель RMSE на тестовой выборке дал значение 41.3, что соответствует условию задачи. На графике видно, что модель предсказывает адекватно, но по всплескам видно, что она ошибается в некоторых местах.

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
# Есть промежуточный вывод - хорошо!
# </div>

# %% [markdown]
# ## Обший вывод
#
# 1. Мы получили данные заказов такси с марта по август 2018 года. Изменили тип данных Datetime с object на datetime64 и установили индекс таблицы равным столбцу Datetime. Проверили на наличие пропусков, на монотонность и ресемплировали данные по часу (изначально данные за каждые 10 минут).
#
# 2. Далее мы проанализировали графики временного ряда, сначала по всем данным, затем по месяцу и по 2 дням и выявили тренд на увеличение количества заказов с течением времени, а также то, что максимум заказов приходится на 12 ночи, а минимум на 6 утра. Проверили на стационарность временного ряда. Затем мы создали календарные признаки для месяца, дня, дня недели и часа и отстающие признаки, а также скользящее среднее. Удалили пропуски и получили таблицу с 29 признаками, готовую для построения моделей.
#
# 3. Затем разделили данные на обучающую и тестовую выборки и обучили модели линейной регрессии, случайного леса и LightGBM. Наилучшее значение метрики RMSE оказалось у LightGBM
#
# 4. Протестировали модель на тестовых данных и получили значение RMSE 41.3.

# %% [markdown]
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
# И про итоговый вывод не забыли - отлично!
# </div>

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Данные загружены и подготовлены
# - [x]  Данные проанализированы
# - [x]  Модель обучена, гиперпараметры подобраны
# - [x]  Качество моделей проверено, выводы сделаны
# - [x]  Значение *RMSE* на тестовой выборке не больше 48

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Елена, ты хорошо потрудилась над этим проектом - работа получилось на довольно высоком уровне!
#
# Ты верно выполнила все задания проекта, последовательно прошла все его шаги, получила верные выводы и ничего не упустила в процессе - это классно, ты молодец!
#
# Ты хорошо используешь визуализацию, умело подбираешь тип графиков для объяснения данных. Понравилось также, что ты не ограничилась использованием простеньких алгоритмов типа линейной регрессии, а использовала более продвинутые инструменты вроде случайного леса бустинга. Также реализован механизм подбора гиперпараметров моделей с учётом специфики временного ряда - несомненный плюс! Также здорово, что в конце работы сравнила предсказанные и истинные значения для понимания узких зон модели - тоже плюс!
#
# Над проектом стоит ещё поработать: свои рекомендации по его улучшению, касающиеся как оформления, так и аналитической части, я оставил в комментариях жёлтого цвета. Также есть критическое замечание о процессе промежуточного тестирования моделей (валидации). Эти комментарии я выделил красным цветом и постарался описать в них верный подход. Будет здорово, если ты учтёшь эти комментарии во время следующей итерации работы над проектом - тогда ценность твоего проекта сильно возрастёт.
#
# Если по тому, что нужно сделать, будут вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью:)
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту v.2.
#
# Елена, спасибо, что прислала работу на повторное ревью - критический комментарий был учтён в работе.
#
# Вместе с тем в работе осталось большое количество неучтённых жёлтых комментариев - при таком количестве активных комментариев я не могу принять твой проект. Жёлтые комментарии, несмотря на невысокую критичность, тоже очень важны, так как повышают общее качество твоего проекта и обращают твоё внимание на не очень критичные, но всё же важные детали проекта или инструментов, их обязательно стоит учитывать. Поэтому будет здорово, если на следующей итерации работы с проектом ты учтёшь оставшиеся комментарии по проекту.
#
# Если возникнут вопросы по реализации - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью:)
#
# Жду твой проект снова!

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту v.3.
#
# Елена, теперь все комментарии были учтены - спасибо!
#
# В проекте остался вопрос о корректности проведения валидации при ручном подборе параметров - я оставил тебе комментарий с подсказками о том, как этот процесс должен выглядеть. Уверен, ты быстро в нём разберёшься, но если будут вопросы - оставляй свои вопросы в комментариях, я отвечу во время следующего ревью:)
#
# Также был вопрос о корректности сплитования выборок при выделении валидационной выборки - также оставил для тебя комментарий:)
#
# Жду твой проект на повторном ревью!

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту v.4.
#
# Елена, вопрос про сплитование выборок снимается - исходный вариант был корректен. В остальном - остался открытым вопрос про корректность валиации. Также я вижу, что в работе активна синтаксическая ошибка, в конце проекта многие ячейки не исполнены и закомментированы - возможно, снова был отправлен несохранённый вариант проекта?

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *надеюсь, сейчас все в порядке*
# </div>
